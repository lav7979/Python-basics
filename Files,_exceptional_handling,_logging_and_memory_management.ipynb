# %% [markdown]
# <a href="https://colab.research.google.com/github/lav7979/Python-basics/blob/main/Files%2C_exceptional_handling%2C_logging_and_memory_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# Answer:
#
#       Interpreted languages execute code line by line using an interpreter (e.g., Python), while compiled languages are translated into machine code using a compiler before execution (e.g., C++).
#
# Example:
#
#       Python (interpreted): Executes code directly.
#       C++ (compiled): Needs to be compiled before running.
#
# 2. What is exception handling in Python?
#
# Answer:
#
#       Exception handling is used to manage runtime errors using try, except, else, and finally blocks.
#
# Example:
#
#
#       try:
#           result = 10 / 0
#       except ZeroDivisionError:
#           print("Cannot divide by zero")
#
# 3.What is the purpose of the finally block in exception handling?
#
# Answer:
#
#       The finally block is used to execute code regardless of whether an exception occurs, typically for cleanup.
#
# Example:
#
#
#       try:
#           f = open("file.txt")
#       finally:
#           f.close()
#
# 4.  What is logging in Python?
#
# Answer:
#       Logging is the process of recording messages to track events and issues in a program.
#
# Example:
#
#       import logging
#       logging.warning("This is a warning")
#
# 5. What is the significance of the __del__ method in Python?
#
# Answer:
#       __del__ is a destructor method called when an object is about to be destroyed to release resources.
#
# Example:
#
#       class MyClass:
#           def __del__(self):
#               print("Object is being deleted")
#
# 6.  What is the difference between import and from ... import in Python?
#
# Answer:
#
#      import module: Imports the whole module.
#
#       from module import name: Imports specific parts of the module.
#
# Example:
#
#         import math
#         print(math.sqrt(16))
#
#         from math import sqrt
#         print(sqrt(16))
#
# 7. How can you handle multiple exceptions in Python?
#
# Answer:
#
#       Use multiple except blocks or a tuple of exceptions.
#
# Example:
#
#         try:
#           x = int("a")
#       except ValueError:
#           print("Value Error")
#       except TypeError:
#           print("Type Error")
#
#
# 8.  What is the purpose of the with statement when handling files in Python?
#
# Answer:
#       It ensures proper acquisition and release of resources like file closing.
#
# Example:
#
#       with open("file.txt", "r") as f:
#           content = f.read()
#
#
# 9.  What is the difference between multithreading and multiprocessing?
#
# Answer:
#
#       Multithreading: Multiple threads in one process; good for I/O-bound tasks.
#
#       Multiprocessing: Multiple processes; good for CPU-bound tasks.
#
# Example:
#
#       threading.Thread() vs multiprocessing.Process()
#
#
# 10.  What are the advantages of using logging in a program?
#
# Answer:
#
#         Tracks program execution
#
#         Helps in debugging
#
#         Can log to files or over networks
#
#
# 11. What is memory management in Python?
#
# Answer:
#
#       Python manages memory using reference counting and garbage collection to allocate and free memory.
#
#
# 12.  What are the basic steps involved in exception handling in Python?
#
# Answer:
#
#         try: Code that may raise an error.
#
#         except: Handles the error.
#
#         else: Runs if no exception.
#
#         finally: Always runs.
#
#
# 13. Why is memory management important in Python?
#
# Answer:
#
#         It ensures efficient use of memory, prevents memory leaks, and maintains performance.
#
#
# 14. What is the role of try and except in exception handling?
#
# Answer:
#
#       try block runs code that may fail; except handles any exceptions that arise.
#
# Example:
#
#
# try:
#
#           print(10 / 0)
#       except ZeroDivisionError:
#           print("Divide by zero error")
#
# 15.  How does Python's garbage collection system work?
#
# Answer:
#
#       Python uses reference counting and a garbage collector to remove unused objects, including those in cyclic references.
#
#
# 16.  What is the purpose of the else block in exception handling?
#
# Answer:
#
#       It runs only if no exception occurs in the try block.
#
# Example:
#
#
# try:
#
#       print("No error")
# except:
#
#       print("Error")
# else:
#
#       print("Success")
#
# 17.  What are the common logging levels in Python?
#
# Answer:
#
#
#         DEBUG
#
#         INFO
#
#         WARNING
#
#         ERROR
#
#         CRITICAL
#
# Example:
#
#         import logging
#         logging.basicConfig(level=logging.DEBUG)
#         logging.debug("Debug message")
#
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# Answer:
#
#
#         os.fork() is Unix-only and low-level.
#
#         multiprocessing is high-level and cross-platform.
#
#
# 19. What is the importance of closing a file in Python?
#
# Answer:
#
#         Releases system resources and ensures data is written properly.
#
#
#  20.  What is the difference between file.read() and file.readline() in Python?
#
# Answer:
#
#       file.read(): Reads the entire file content as a single string.
#
#       file.readline(): Reads one line from the file at a time.
#
# Example:
#
#
#       with open("sample.txt", "r") as f:
#           content = f.read()         # Reads all content
#           # or
#           line = f.readline()        # Reads one line
#
#
# 21.  What is the logging module in Python used for?
#
# Answer:
#
#         The logging module is used to track events that happen during program execution, for debugging and monitoring.
#
# Example:
#
#         import logging
#         logging.basicConfig(level=logging.INFO)
#         logging.info("This is an info message")
#
#
# 22. What is the os module in Python used for in file handling?
#
# Answer:
#
#       The os module is used for interacting with the operating system, such as managing files and directories.
#
# Example:
#
#         import os
#         os.rename("old.txt", "new.txt")
#         os.remove("new.txt")
#
#
# 23.  What are the challenges associated with memory management in Python?
#
# Answer:
#
#
#         Circular references can prevent memory from being freed.
#
#         Memory leaks may occur due to lingering references.
#
#         Garbage collector overhead can affect performance.
#
#         Limited manual control compared to low-level languages.
#
#
#
# 24.  How do you raise an exception manually in Python?
#
# Answer:
#
#         Use the raise keyword to manually throw an exception.
#
# Example:
#
#         raise ValueError("Invalid input detected")
#
#
# 25.  Why is it important to use multithreading in certain applications?
#
# Answer:
#
#           Multithreading allows programs to:
#
#           Perform multiple tasks concurrently.
#
#           Stay responsive (e.g., in GUIs).
#
#           Handle I/O-bound tasks more efficiently.
#
# Example:
#
#           import threading
#
#           def print_numbers():
#               for i in range(5):
#                   print(i)
#
#           thread = threading.Thread(target=print_numbers)
#           thread.start()
#
#
#
#
#           Practical
#
#
#  1.  How can you open a file for writing in Python and write a string to it?
#
# Answer:
#
#       Use open() with "w" mode.
#
# Example:
#
#           with open("output.txt", "w") as f:
#               f.write("Hello, Python!")
#
# Output:
#
#          Hello, Python!
#
#
# 2. Write a Python program to read the contents of a file and print each line?
#
# Example:
#
#
#           with open("example.txt", "r") as f:
#               for line in f:
#                   print(line.strip())
# Output:
#
#       Line 1
#       Line 2
#
#
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?
#
# Example:
#
#
#           try:
#
#               with open("nonexistent.txt", "r") as f:
#                   print(f.read())
#           except FileNotFoundError:
#               print("File not found.")
# Output:
#
#       File not found.
#
#
# 4.  Write a Python script that reads from one file and writes its content to another file?
#
# Example:
#
#           with open("source.txt", "r") as src, open("copy.txt", "w") as dest:
#               for line in src:
#                   dest.write(line)
#
# Output :
#
#         (Same content as in source.txt)
#
#
# 5.  How would you catch and handle division by zero error in Python?
#
# Example:
#
#
#
#           try:
#             print(5 / 0)
#           except ZeroDivisionError:
#             print("Cannot divide by zero.")
# Output:
#
#       Cannot divide by zero.
#
#
# 6.  Write a Python program that logs an error message to a log file when a division by zero exception occurs?
#
# Example:
#
#           import logging
#
#           logging.basicConfig(filename="error.log", level=logging.ERROR)
#
#           try:
#
#               result = 10 / 0
#           except ZeroDivisionError as e:
#               logging.error("Division by zero occurred", exc_info=True)
#
# Output:
#
#
#         ERROR:root:Division by zero occurred
#         Traceback (most recent call last):
#
#         ZeroDivisionError: division by zero
#
# 7.  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
#
# Example:
#
#
#           import logging
#
#           logging.basicConfig(level=logging.DEBUG)
#
#           logging.info("Info message")
#           logging.warning("Warning message")
#           logging.error("Error message")
#
# Output:
#
#           INFO:root:Info message
#           WARNING:root:Warning message
#           ERROR:root:Error message
#
#
# 8.  Write a program to handle a file opening error using exception handling?
#
# Example:
#
#
#             try:
#             with open("file.txt", "r") as f:
#                 print(f.read())
#             except IOError:
#                 print("Error opening file.")
#
# Output:
#
#         Error opening file.
#
#
# 9.  How can you read a file line by line and store its content in a list in Python?
#
# Example:
#
#
#             with open("data.txt", "r") as f:
#                 lines = [line.strip() for line in f]
#             print(lines)
# Output:
#
#             ['Line 1', 'Line 2', 'Line 3']
#
# 10.  How can you append data to an existing file in Python?
#
# Example:
#
#
#           with open("log.txt", "a") as f:
#               f.write("New log entry\n")
#
# Output:
#
#           ... (previous content)
#           New log entry
#
#
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist?
#
# Example:
#
#
#           data = {"name": "Alice"}
#
#   try:
#         print(data["age"])
#
#   except KeyError:
#
#            print("Key not found.")
# Output:
#
#       Key not found.
#
# 12.  Write a program that demonstrates using multiple except blocks to handle different types of exceptions?
#
# Example:
#
#
#   try:
#         x = int("abc")
#         y = 10 / 0
#   except ValueError:
#
#         print("ValueError occurred")
#
#   except ZeroDivisionError:
#
#       print("ZeroDivisionError occurred")
# Output:
#
#      ValueError occurred
#
# 13.  How would you check if a file exists before attempting to read it in Python?
#
# Example:
#
#
#       import os
#
#       if os.path.exists("sample.txt"):
#           with open("sample.txt", "r") as f:
#               print(f.read())
#       else:
#
# Output:
#
#         (File content or 'File does not exist.')
#
# 14.  Write a program that uses the logging module to log both informational and error messages?
#
# Example:
#
#
# import logging
#
#         logging.basicConfig(filename="logfile.log", level=logging.INFO)
#         logging.info("Program started")
#
#         try:
#             1 / 0
#         except ZeroDivisionError:
#             logging.error("Division by zero")
#
# Output:
#
#           INFO:root:Program started
#           ERROR:root:Division by zero
#
# 15.  Write a Python program that prints the content of a file and handles the case when the file is empty?
#
# Example:
#
#
#         with open("maybe_empty.txt", "r") as f:
#             content = f.read()
#
#             if content:
#                 print(content)
#
#             else:
#                 print("File is empty.")
#
# Output:
#
#           File is empty.  (or file contents)
#
#
# 16.  Demonstrate how to use memory profiling to check the memory usage of a small program?
#
# Example:
#
#
#         from memory_profiler import profile
#
#             @profile
#             def create_list():
#                 data = [i for i in range(10000)]
#                 return data
#
#               create_list()
#               Run with:
#
#           python -m memory_profiler script.py
#
# Output:
#
#         Line #    Mem usage    Increment   Line Contents
#         ...       13.5 MiB     +0.4 Mi
#
#
#
# 17  Write a Python program to create and write a list of numbers to a file, one number per line?
#
# Example:
#
#
#                 numbers = [1, 2, 3, 4, 5]
#
#                 with open("numbers.txt", "w") as f:
#                     for number in numbers:
#
# Output:
#
#
#                 1
#                 2
#                 3
#                 4
#                 5
#
# 18  How would you implement a basic logging setup that logs to a file with rotation after 1MB?
# Example:
#
#
#             import logging
#             from logging.handlers import RotatingFileHandler
#
#                   handler = RotatingFileHandler("rotating.log", maxBytes=1024*1024, backupCount=3)
#                   logging.basicConfig(level=logging.INFO, handlers=[handler])
#
#                 for i in range(10000):
#                     logging.info("This is log entry number %d", i)
#
# Output:
#
#               Rotates log file after reaching ~1MB
#
#              Creates rotating.log, rotating.log.1, etc.
#
# 19  Write a program that handles both IndexError and KeyError using a try-except block?
#
# Example:
#
#
#             data = {"name": "Alice"}
#             lst = [1, 2, 3]
#
#                 try:
#                     print(data["age"])
#                     print(lst[5])
#
#                 except KeyError:
#                     print("Key not found.")
#
#                 except IndexError:
#                     print("Index out of range.")
# Output:
#
#             Key not found.
#
#
# 20  How would you open a file and read its contents using a context manager in Python?
#
# Example:
#
#             with open("example.txt", "r") as f:
#                 content = f.read()
#                 print(content)
#
# Output:
#           Prints the contents of example.txt safely and automatically closes the file afterward.
#
#
# 21  Write a Python program that reads a file and prints the number of occurrences of a specific word?
#
# Example:
#
#               word_to_count = "python"
#               count = 0
#
#               with open("example.txt", "r") as f:
#                   for line in f:
#                       count += line.lower().count(word_to_count)
#
#                         print(f"'{word_to_count}' occurred {count} times.")
#
#
# Output:
#
#             'python' occurred 3 times.
#
#
# 22  How can you check if a file is empty before attempting to read its contents?
#
# Example:
#
#
#           import os
#
#           if os.path.getsize("maybe_empty.txt") == 0:
#               print("File is empty.")
#                   else:
#                       with open("maybe_empty.txt", "r") as f:
#                           print(f.read())
#
# Output:
#
#             File is empty.  (or prints file content)
#
#
# 23 Write a Python program that writes to a log file when an error occurs during file handling?
# Example:
#
#               import logging
#
#               logging.basicConfig(filename="file_error.log", level=logging.ERROR)
#
#                       try:
#                           with open("non_existent_file.txt", "r") as f:
#                               data = f.read()
#                       except Exception as e:
#                           logging.error("Error while handling file: %s", str(e))
#                           print("An error occurred. Check log.")
#
#
# Output:
#
#                An error occurred. Check log.
#                Output in file_error.log:
#
#
#               ERROR:root:Error while handling file: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %% [markdown]
# # New section
