# %% [markdown]
# <a href="https://colab.research.google.com/github/lav7979/Python-basics/blob/main/Data_Types_and_Structures_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 What are data structures, and why are they important?
#
#      Data structures are ways of organizing and storing data so that it can be accessed and modified efficiently. They are crucial for building efficient algorithms and software systems.
#
#
# 2 Explain the difference between mutable and immutable data types with examples?
#
#      Mutable: Can be changed after creation (e.g., list, dict, set).
#       my_list = [1, 2, 3]
#       my_list[0] = 10
#      Immutable: Cannot be changed after creation (e.g., int, float, str, tuple).
#       my_str = "hello"
#       my_str[0] = "H"
#
# 3 What are the main differences between lists and tuples in Python?
#
#       Lists are mutable and slower.
#
#       Tuples are immutable and faster.
#
#
# 4 Describe how dictionaries store data?
#
#       Dictionaries store data in key-value pairs using a hash table under the hood for fast lookup.
#
#
#
# 5  Why might you use a set instead of a list in Python?
#
#       Sets automatically remove duplicates and provide faster membership checks (in operations).
#
# 6  What is a string in Python, and how is it different from a list?
#
#       A string is an immutable sequence of characters, while a list is a mutable sequence that can hold any data type.
#
# 7  How do tuples ensure data integrity in Python?
#
#       Tuples are immutable, so once created, their contents can't be changed—protecting data from accidental modification.
#
# 8  What is a hash table, and how does it relate to dictionaries in Python?
#
#      A hash table maps keys to values using a hashing function. Python’s dict uses this structure for fast key-based access.
#
# 9  Can lists contain different data types in Python?
#
#       Yes, lists can hold mixed data types
#       my_list = [1, "two", 3.0, [4]
#
# 10  Explain why strings are immutable in Python?
#
#      Strings are immutable for performance and security reasons—it avoids unintended side effects during reuse or sharing.
#
# 11  What advantages do dictionaries offer over lists for certain tasks?
#
#      Dictionaries offer faster lookups by key and better organization for data with named elements.
#
#
# 12  Describe a scenario where using a tuple would be preferable over a list?
#
#
#      Use a tuple when storing configuration settings or fixed coordinate pairs that shouldn't change:
#       location = (40.7128, -74.0060)
#
# 13  How do sets handle duplicate values in Python?
#
#      Sets automatically remove duplicates:
#      set([1, 2, 2, 3])  # Result: {1, 2, 3}
#
# 14  How does the “in” keyword work differently for lists and dictionaries?
#
#
#      List: Checks if the value exists.
#      Dict: Checks if the key exists.
#      apple" in ["apple", "banana"]
#      True"apple" in {"apple": 1}
#
# 15  Can you modify the elements of a tuple? Explain why or why not?
#
#       No, tuples are immutable. Attempting to modify them results in a TypeError.
#
#
# 16  What is a nested dictionary, and give an example of its use case?
#       A nested dictionary is a dictionary within another dictionary. It allows you to store structured or hierarchical data — for example, details of multiple students, where each student has their own sub-dictionary of attributes.
#
#      students = {
#      "1001": {"name": "Alice", "grade": "A"},
#      "1002": {"name": "Bob", "grade": "B"}
#
# 17  Describe the time complexity of accessing elements in a dictionary?
#
#      Average-case time complexity is O(1) due to hashing.
#
# 18  In what situations are lists preferred over dictionaries?
#
#      When you need ordered, sequential data or index-based access.
#
# 19  Why are dictionaries considered unordered, and how does that affect data retrieval?
#
#       Before Python 3.7, dictionaries were unordered. Now they maintain insertion order, but key-based access—not position—is used for retrieval.
#
#
# 20  Explain the difference between a list and a dictionary in terms of data retrieval?
#
#      List: Access by index (e.g., list[0]).
#      Dictionary: Access by key (e.g., dict["key"]).
#
#
# Practical Questions
#
#
#
# 1  Write a code to create a string with your name and print it?
#
#      name = "lav"
#      print(name)
#      # O/P: Lav
#
# 2  Write a code to find the length of the string "Hello World"?
#
#      s = "Hello World"
#      print(len(s))
#      # O/P:10
#
# 3  Write a code to slice the first 3 characters from the string "Python Programming"?
#
#       s = "Python Programming"
#       print(s[:3])
#       # O/P: Pyt
#
# 4  Write a code to convert the string "hello" to uppercase?
#
#      s = "hello"
#      print(s.upper())
#      # O/P:HELLO
#
# 5  Write a code to replace the word "apple" with "orange" in the string "I like apple"?
#
#      s = "I like apple"
#      print(s.replace("apple", "orange"))
#      # O/P: I like orange
#
# 6  Write a code to create a list with numbers 1 to 5 and print it?
#
#      numbers = [1, 2, 3, 4, 5]
#      print(numbers)
#      # O/P:[1,2,3,4,5]
#
# 7   Write a code to append the number 10 to the list [1, 2, 3, 4]?
#
#      numbers = [1, 2, 3, 4]
#      numbers.append(10)
#      print(numbers)
#      # O/P:[1,2,3,4,10]
#
# 8  Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]?
#
#      numbers = [1, 2, 3, 4, 5]
#      numbers.remove(3)
#      print(numbers)
#      # O/P:[1,2,4,5]
#
# 9  Write a code to access the second element in the list ['a', 'b', 'c', 'd']?
#
#      letters = ['a', 'b', 'c', 'd']
#      print(letters[1])
#      # O/P:[b]
#
# 10  Write a code to reverse the list [10, 20, 30, 40, 50]?
#
#      numbers = [10, 20, 30, 40, 50]
#      numbers.reverse()
#      print(numbers)
#      # O/P:[50,40,30,20,10]
#
# 11 Write a code to create a tuple with the elements 100, 200, 300 and print it?
#
#       my_tuple = (100, 200, 300)
#       print(my_tuple)
#       # O/P:(100, 200, 300)
#
# 12  Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')?
#
#       colors = ('red', 'green', 'blue', 'yellow')
#       print(colors[-2])
#        # O/P:blue
# 13 Write a code to find the minimum number in the tuple (10, 20, 5, 15)?
#
#
#
#       numbers = (10, 20, 5, 15)
#       print(min(numbers))
#       #O/P:5
#
# 14  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')?
#
#      animals = ('dog', 'cat', 'rabbit')
#      print(animals.index('cat'))
#      #O/P:1
#
# 15 Write a code to create a tuple containing three different fruits and check if "kiwi" is in it?
#
#
#       fruits = ('apple', 'banana', 'cherry')
#       print('kiwi' in fruits)
#       #O/P: FALSE
#
# 16 Write a code to create a set with the elements 'a', 'b', 'c' and print it?
#
#      my_set = {'a', 'b', 'c'}
#      print(my_set)
#       # O/P: {'a', 'b', 'c'}
#
# 17 Write a code to clear all elements from the set {1, 2, 3, 4, 5}?
#
#      numbers = {1, 2, 3, 4, 5}
#      numbers.clear()
#      print(numbers)
#        # O/P: {}
#
# 18 Write a code to remove the element 4 from the set {1, 2, 3, 4}?
#
#      numbers = {1, 2, 3, 4}
#      numbers.remove(4)
#      print(numbers)
#        # O/P: {1,2,3}
#
# 19 Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}?
#
#      set1 = {1, 2, 3}
#      set2 = {3, 4, 5}
#      union_set = set1.union(set2)
#      print(union_set)
#        # O/P: {1,2,4,5}
#
# 20 Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}?
#
#      set1 = {1, 2, 3}
#      set2 = {2, 3, 4}
#      intersection = set1.intersection(set2)
#      print(intersection)
#      #O/P: {2, 3}
#
# 21 Write a code to create a dictionary with the keys "name", "age", and "city", and print it?
#
#      person = {"name": "Alice", "age": 30, "city": "Paris"}
#      print(person)
#      #O/P: {"name": "Alice", "age": 30, "city": "Paris"}
#
# 22 Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}?
#
#      person = {'name': 'John', 'age': 25}
#      person['country'] = 'USA'
#      print(person)
#        #O/P: {'name': 'John', 'age': 25, 'country' : 'USA'}
#
# 23 Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}?
#
#      person = {'name': 'Alice', 'age': 30}
#      print(person['name'])
#       #O/P: Alice
#
# 24 Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}?
#
#       person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
#       del person['age']
#       print(person)
#        #O/P: {'name': 'Bob', 'city': 'New York'}
#
# 25 Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}?
#
#      person = {'name': 'Alice', 'city': 'Paris'}
#      print('city' in person)
#      #O/P: True
#
# 26 Write a code to create a list, a tuple, and a dictionary, and print them all?
#
#      my_list = [1, 2, 3]
#      my_tuple = (4, 5, 6)
#      my_dict = {"a": 1, "b": 2}
#      print(my_list, my_tuple, my_dict)
#       #O/P:[1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}
#
# 27 Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result?(replaced)
#
#      import random
#      numbers = random.sample(range(1, 101), 5)
#      numbers.sort()
#      print(numbers)
#      #O/P:[12, 34, 45, 67, 89]
#
# 28 Write a code to create a list with strings and print the element at the third index?
#
#      words = ["apple", "banana", "cherry", "date", "fig"]
#      print(words[3])
#      #O/P: date
#
# 29 Write a code to combine two dictionaries into one and print the result?
#
#      dict1 = {"a": 1, "b": 2}
#      dict2 = {"c": 3, "d": 4}
#      combined = {**dict1, **dict2}
#      print(combined)
#      #O/P: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
#
# 30 Write a code to convert a list of strings into a set?
#
#      words = ["apple", "banana", "cherry", "apple"]
#      words_set = set(words)
#      print(words_set)
#      #O/P:{'banana', 'cherry', 'apple'}
