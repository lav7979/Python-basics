# %% [markdown]
# <a href="https://colab.research.google.com/github/lav7979/Python-basics/blob/main/Analysis_of_Olympic_Medal_Trends_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Code_Generated_Image (1).png](data:image/png;base64,...)

# %% [markdown]
# ![Code_Generated_Image (2).png](data:image/png;base64,...)

# %% [markdown]
# ![Code_Generated_Image (3).png](data:image/png;base64,...)

# %% [markdown]
# ![Code_Generated_Image (4).png](data:image/png;base64,...)

# %% [markdown]
#
#
#
#           Module 1: Country Dominance,"USA holds massive historical dominance (4,335 medals). Concentration of success in former Soviet-bloc nations (URS, GDR) confirms high-investment impact.",Investment Strategy: Advise NOCs to conduct Cost-per-Medal Analysis to optimize ROI and guide funding towards the most efficient disciplines.
#           Module 4: Sport Density,"Aquatics and Athletics are the highest medal-yielding sports, offering the greatest collective medal potential for a country.",Prioritize High-Yield Sports: Encourage countries to focus major investment and training resources on Aquatics and Athletics to maximize overall medal volume.
#           Module 2: Athlete Excellence,Top athletes like Larisa Latynina (18) and Michael Phelps (16) achieve high density by dominating multiple events across several Olympic cycles.,"Talent Identification Models: Build predictive models based on the patterns of these repeat performers to optimize early-stage talent pipelines for sustained, multi-cycle success."
#           Module 3: Gender Dynamics,"Women's medal volume was negligible until the 1980s but shows a dramatic rise post-1992, indicating policy effectiveness.",Gender Equity Roadmap: The IOC must continue to enforce gender participation quotas and promote women's events globally to push for full parity.

# %% [markdown]
#         Area,Component (Visualization),Data Field Used,Strategic Purpose
#       A. Control Panel (Filters),Global Filters,"Edition (Year Slider), Medal (Filter), Performance Category (Calculated Field)",Controls the scope and tier of analysis for the entire dashboard.
#       B. Macro Trends (Top),Module 1: Country Distribution (Bar Chart/Map),"NOC, COUNT(Medal)",Identifies macro country dominance trends.
#       C. Performance & Policy (Bottom),Module 4: Sport-Specific Trends (Stacked Bar Chart),"Sport, Medal",Guides Investment Strategy by highlighting high-density sports.
#       ,Module 3: Temporal Gender Analysis (Dual-Line Chart),"Edition, Gender, COUNT(Medal)",Informs Gender Equity Roadmap by tracking participation evolution.
#       ,Module 2: Athlete Density (Ranked Table/Bar Chart),"Athlete, COUNT(Medal)",Supports Talent Identification by spotting repeat champions.

# %% [markdown]
#       ction Trigger	Action Result	Policy Link
#       Click on a Country (Module 1 Bar)	Filters Module 3 (Gender Analysis) to show only that country's male/female medal trends over time.	Country Performance over time.
#       Click on a Sport (Module 4 Bar)	Filters Module 2 (Athlete Density) to show the top athletes only within that selected sport.	Talent Identification within high-yield areas.
#       Use Performance Category Filter	Filters all charts to show only medals that match the selected tier (e.g., viewing only 'Elite Champions').	Excellence Benchmarking

# %% [markdown]
#       Edition,Year,Men (Total Medals),Women (Total Medals)
#       1896,1896,151,0
#       1900,1900,501,11
#       1904,1904,458,12
#       1908,1908,789,15
#       1912,1912,855,30
#       1920,1920,"1,255",43
#       1924,1924,833,51
#       1928,1928,615,95
#       1932,1932,555,60
#       1936,1936,791,84
#       1948,1948,718,96
#       1952,1952,750,139
#       1956,1956,739,146
#       1960,1960,737,145
#       1964,1964,820,190
#       1968,1968,819,212
#       1972,1972,947,238
#       1976,1976,924,381
#       1980,1980,958,429
#       1984,1984,973,486
#       1988,1988,"1,011",535
#       1992,1992,"1,105",600
#       1996,1996,"1,082",777
#       2000,2000,"1,126",889
#       2004,2004,"1,099",899
#       2008,2008,"1,110",932

# %% [markdown]
#         Athlete,Total Medals
#         "Latynina, Larisa",18
#         "Phelps, Michael",16
#         "Andrianov, Nikolay",15
#         "Ono, Takashi",13
#         "Mangiarotti, Edoardo",13
#         "Shakhlin, Boris",13
#         "Nurmi, Paavo",12
#         "Nemov, Alexei",12
#         "Fischer, Birgit",12
#         "Torres, Dara",12
