# %% [markdown]
# <a href="https://colab.research.google.com/github/lav7979/Python-basics/blob/main/Supply_Chain_Performance_Analytics_for_GlamourGlow_Cosmetics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#         1.Tableau Dashboard Layout
#
#         GlamourGlow Cosmetics  Supply Chain Command Center
#
#          DASHBOARD STRUCTURE (High Level)
#          Dashboard 1: Executive Overview
#          Dashboard 2: Inventory Intelligence
#          Dashboard 3: Supplier & Quality Performance
#          Dashboard 4: Logistics & Cost Analysis
#          DASHBOARD 1: EXECUTIVE OVERVIEW
#
#          Objective
#
#         Top management ko overall supply chain health dikhana.
#
#               Sheet 1: KPI Tiles
#
#               Sheets Banayein:
#
#               Total Revenue
#
#               Total Units Sold
#
#               Inventory Turnover
#
#               On-Time Delivery %
#
#               Total Supply Chain Cost
#
#               How to Build (Example – Revenue KPI):
#
#               Rows → SUM(Revenue generated)
#
#               Marks → Text
#
#               Format → Large bold font
#
#
#
#           Sheet 2: Revenue by Product Type
#
#           Chart Type: Bar Chart
#
#           Columns → Product type
#
#           Rows → SUM(Revenue generated)
#
#           Color → Product type
#
#
#         Insight:
#
#         Kaunsa product category (haircare / skincare / cosmetics) sabse zyada revenue la raha hai.
#
#
#         Sheet 3: Cost vs Revenue Trend
#
#         Chart Type: Dual Axis Line
#
#         Columns → SKU (or Product type)
#
#         Rows → Revenue generated & Total Supply Chain Cost
#
#
#             Insight:
#
#             Cost increase ke saath profitability impact.
#
#              DASHBOARD 2: INVENTORY INTELLIGENCE
#
#              Objective
#
# Stockout & Overstock detect karna.
#
#
#             Sheet 4: Stock Risk by SKU
#
#             Chart Type: Heatmap
#
#             Rows → SKU
#
#             Columns → Low Stock Flag
#
#             Color → Stock levels
#
#
#           Insight:
#
#           Kaunse SKUs high stockout risk me hain.
#
#
#             Sheet 5: High Demand – Low Stock
#
#             Chart Type: Bar Chart
#
#             Rows → SKU
#
#             Columns → Number of products sold
#
#             Filter → Stock levels < 20
#
#
#             Insight:
#
#             Immediate replenishment required products.
#
#
#             Sheet 6: Overstocked Products
#
#             Chart Type: Bar Chart
#
#             Rows → SKU
#
#             Columns → Stock levels
#
#             Filter → Overstock Indicator = “Overstock”
#
#
#  DASHBOARD 3: SUPPLIER & QUALITY PERFORMANCE
#
#               Objective
#
#               Supplier risk & quality issues identify karna.
#
#
#               Sheet 7: Supplier Lead Time Analysis
#
#               Chart Type: Box Plot
#
#               Columns → Supplier name
#
#               Rows → Lead time
#
#
#                 Insight:
#
#                 Kaunse suppliers delay kar rahe hain.
#
#
#                         Sheet 8: Defect Rate vs Lead Time
#
#                         Chart Type: Scatter Plot
#
#                         Columns → AVG(Lead time)
#
#                         Rows → AVG(Defect rates)
#
#                         Color → Supplier name
#
#                         Size → Production volumes
#
#
#             Insight:
#
#             High defect + high lead time suppliers = risk.
#
#
#             Sheet 9: Supplier Scorecard Table
#
#             Chart Type: Table
#
#             Rows → Supplier name
#
#             Measures → Supplier Score, Defect Rate %, Avg Lead Time
#
#
#         DASHBOARD 4: LOGISTICS & COST ANALYSIS
#         Objective
#
#         Delivery delays & logistics cost control.
#
#
#               Sheet 10: Carrier Performance
#
#               Chart Type: Bar Chart
#
#               Rows → Shipping carriers
#
#               Columns → AVG(Shipping times)
#
#             Insight:
#
#             Kaunsa carrier sabse slow hai.
#
#
#               Sheet 11: Transportation Mode Cost
#
#               Chart Type: Bar Chart
#
#               Rows → Transportation modes
#
#               Columns → AVG(Costs)
#
#
#                       Insight:
#
#                       Air expensive, Road economical, etc.
#
#
#                   Sheet 12: Route Cost Analysis
#
#                   Chart Type: Heatmap
#
#                   Rows → Routes
#
#                   Columns → Location
#
#                   Color → AVG(Costs)
#
#                    DASHBOARD INTERACTIVITY (IMPORTANT )
#
#
#                 Product type
#
#                   Supplier name
#
#                   Location
#
#                   Transportation modes
#
#
#
#                   Lead Time Threshold
#
#                   Stock Level Threshold
#
#
#           ✔ Actions
#
#           Click supplier → Filter inventory & logistics
#
#           Hover → Tooltip with defect & cost info
#
#
#                   ┌─────────────────────────────────────────────────────────────┐
#         │  TOTAL REVENUE   |  UNITS SOLD  |  INVENTORY TURNOVER | OTD% │
#         │  ₹ XX,XXX        |  XX,XXX      |      4.8x           | 95%  │
#         └─────────────────────────────────────────────────────────────┘
#
#         ┌─────────────────────────────┬───────────────────────────────┐
#         │ Revenue by Product Type     │ Cost by Product Type           │
#         │ (Bar Chart)                 │ (Bar Chart)                    │
#         │ Haircare | Skincare | Cosmo │ Manufacturing + Logistics      │
#         └─────────────────────────────┴───────────────────────────────┘
#
#            [ Filters: Product Type | Location | Supplier ]
#
#
#                 ┌─────────────────────────────────────────────────────────────┐
#       │ SKU vs STOCK LEVEL HEATMAP                                   │
#       │ (Color = Stock Level, Size = Units Sold)                     │
#       └─────────────────────────────────────────────────────────────┘
#
#       ┌─────────────────────────────┬───────────────────────────────┐
#       │ High Demand – Low Stock     │ Overstocked SKUs               │
#       │ (Bar Chart)                 │ (Bar Chart)                    │
#       │ Filter: Stock < 20          │ High Stock + Low Sales         │
#       └─────────────────────────────┴───────────────────────────────┘
#
#
#
#           ┌─────────────────────────────┬───────────────────────────────┐
#       │ Avg Lead Time by Supplier   │ Lead Time vs Defect Rate       │
#       │ (Bar Chart)                 │ (Scatter Plot)                │
#       │                             │ Size = Production Volume      │
#       └─────────────────────────────┴───────────────────────────────┘
#
#       ┌─────────────────────────────────────────────────────────────┐
#       │ SUPPLIER SCORECARD TABLE                                     │
#       │ Supplier | Avg Lead Time | Defect Rate | Inspection Result   │
#       └─────────────────────────────────────────────────────────────┘
#
#
#
#         ┌─────────────────────────────┬───────────────────────────────┐
#       │ Avg Shipping Time by Carrier│ Cost by Transportation Mode    │
#       │ (Bar Chart)                 │ (Bar Chart)                    │
#       └─────────────────────────────┴───────────────────────────────┘
#
#       ┌─────────────────────────────────────────────────────────────┐
#       │ ROUTE vs LOCATION COST HEATMAP                                │
#       │ (Color = Avg Logistics Cost)                                 │
#       └─────────────────────────────────────────────────────────────┘
#
#                 | Purpose               | Color      | Hex Code  |
#           | --------------------- | ---------- | --------- |
#           | Revenue / Sales       | Deep Blue  | `#1F4E79` |
#           | Inventory Normal      | Teal       | `#2CA58D` |
#           | Success / On-Time     | Green      | `#2E7D32` |
#           | Warning / Medium Risk | Amber      | `#F9A825` |
#           | Critical Risk / Late  | Red        | `#C62828` |
#           | Cost / Expense        | Dark Red   | `#8E0000` |
#           | Background            | Light Grey | `#F5F6FA` |
#           | Text / Titles         | Charcoal   | `#263238` |
#
#
#
#
#
#
#
#               | SKU  | Product Type | Price | Sold | Revenue | Stock | Lead Time | Shipping Cost | Supplier   | Inspection Result | Defect Rate |
#         | ---- | ------------ | ----- | ---- | ------- | ----- | --------- | ------------- | ---------- | ----------------- | ----------- |
#         | SKU0 | Haircare     | 69.81 | 802  | 8661.99 | 58    | 29        | 2.95          | Supplier 3 | Pending           | 0.23        |
#         | SKU1 | Skincare     | 14.84 | 736  | 7460.90 | 53    | 23        | 9.72          | Supplier 3 | Pending           | 4.85        |
#         | …    | …            | …     | …    | …       | …     | …         | …             | …          | …                 | …           |
#
#
#
#
#
#
#                 | Product Type | SKU  | Price | Availability | Units Sold | Revenue | Customer Demographics | Stock Level | Lead Time | Supplier   | Location | Shipping Carrier | Shipping Cost |
#         | ------------ | ---- | ----- | ------------ | ---------- | ------- | --------------------- | ----------- | --------- | ---------- | -------- | ---------------- | ------------- |
#         | Haircare     | SKU0 | 69.81 | 55           | 802        | 8661.99 | Non-binary            | 58          | 7         | Supplier 3 | Mumbai   | Carrier B        | 2.96          |
#         | Skincare     | SKU1 | 14.84 | 95           | 736        | 7460.90 | Female                | 53          | 30        | Supplier 3 | Mumbai   | Carrier A        | 9.72          |
#         | Haircare     | SKU2 | 11.32 | 34           | 8          | 9577.75 | Unknown               | 1           | 10        | Supplier 1 | Mumbai   | Carrier B        | 8.05          |
#         | Skincare     | SKU3 | 61.16 | 68           | 83         | 7766.84 | Non-binary            | 23          | 13        | Supplier 5 | Kolkata  | Carrier C        | 1.73          |
#         | …            | …    | …     | …            | …          | …       | …                     | …           | …         | …          | …        | …                | …             |
#
#
#
#
#                     | SKU  | Revenue Trend | Units Sold Trend |
#             | ---- | ------------- | ---------------- |
#             | SKU0 | ▇▆▆▅▅▃▃       | ▆▆▆▅▅▃           |
#             | SKU1 | ▆▅▅▃▃▃        | ▆▆▅▅▃            |
#             | SKU2 | ▇▇▆▅▃         | ▅▅▃▃             |
#
#
#
#
#                     | Product Type | Total Sold | Revenue | Avg Price | Avg Lead Time | Avg Defect Rate | Stock Level |
#         | ------------ | ---------- | ------- | --------- | ------------- | --------------- | ----------- |
#         | Haircare     | 12,345     | $85,000 | $45.23    | 15 days       | 2.5%            | 75          |
#         | Skincare     | 15,678     | $90,500 | $30.12    | 20 days       | 3.8%            | 50          |
#         | Cosmetics    | 10,234     | $78,000 | $55.67    | 12 days       | 1.2%            | 60          |
#
#
#
#
#
#             | Product Type | Total Sold | Revenue | Avg Price | Avg Lead Time | Avg Defect Rate | Stock Level |
#       | ------------ | ---------- | ------- | --------- | ------------- | --------------- | ----------- |
#       | Haircare     | 12,345     | 85,000  | 45.23     | 15 days       | 2.5%            | 75          |
#       | Skincare     | 15,678     | 90,500  | 30.12     | 20 days       | 3.8%            | 50          |
#       | Cosmetics    | 10,234     | 78,000  | 55.67     | 12 days       | 1.2%            | 60          |
#
#
#
#
#               | Warehouse  | Product ID | Inventory | Safety Stock | Status       |
#         | ---------- | ---------- | --------- | ------------ | ------------ |
#         | East Zone  | SKU001     | 10        | 25           | Understocked |
#         | West Zone  | SKU002     | 50        | 40           | Healthy      |
#         | North Zone | SKU003     | 90        | 40           | Overstocked  |
#
#
#
#
#                 | Warehouse  | SKU001 | SKU002 | SKU003 | SKU004 |
#         | ---------- | ------ | ------ | ------ | ------ |
#         | East Zone  | 🔴 10  | 🟢 50  | 🟠 90  | 🟢 60  |
#         | West Zone  | 🟢 45  | 🔴 12  | 🟢 80  | 🟠 70  |
#         | North Zone | 🟠 75  | 🟢 60  | 🔴 15  | 🟢 55  |
#
#
#
#
#               | SKU    | Inventory | Safety Stock | Reorder Point | Status          |
#       | ------ | --------- | ------------ | ------------- | --------------- |
#       | SKU001 | 10        | 25           | 20            | 🔴 Understocked |
#       | SKU002 | 50        | 40           | 30            | 🟢 Healthy      |
#       | SKU003 | 90        | 40           | 30            | 🟠 Overstocked  |
#
#
#
#                 | Warehouse  | SKU001 | SKU002 | SKU003 | SKU004 |
#           | ---------- | ------ | ------ | ------ | ------ |
#           | East Zone  | 🔴 10  | 🟢 50  | 🟠 90  | 🟢 60  |
#           | West Zone  | 🟢 45  | 🔴 12  | 🟢 80  | 🟠 70  |
#           | North Zone | 🟠 75  | 🟢 60  | 🔴 15  | 🟢 55  |
#
#
#
#
#
#                 | Region | Total Orders | Avg Delivery Time | On-Time % | Late Orders |
#       | ------ | ------------ | ----------------- | --------- | ----------- |
#       | East   | 1200         | 4.5               | 95%       | 60          |
#       | West   | 950          | 5.2               | 90%       | 95          |
#       | North  | 700          | 4.8               | 92%       | 55          |
#       | South  | 800          | 6.0               | 85%       | 120         |
#
#
#
#
#
#           | Order ID | Order Date | Region | Delivery Time | Status  |
#         | -------- | ---------- | ------ | ------------- | ------- |
#         | ORD001   | 01-Jan     | East   | 4             | On-Time |
#         | ORD002   | 02-Jan     | West   | 6             | Late    |
#         | ORD003   | 03-Jan     | South  | 5             | On-Time |
#
#
#
#
#                     | Supplier ID | Supplier Name | Avg Lead Time | Defect % | Unit Cost | Status     |
#               | ----------- | ------------- | ------------- | -------- | --------- | ---------- |
#               | SUP001      | Supplier A    | 12            | 1.5%     | $25       | 🟢 Good    |
#               | SUP002      | Supplier B    | 18            | 3.8%     | $22       | 🟠 Average |
#               | SUP003      | Supplier C    | 25            | 6.2%     | $28       | 🔴 Poor    |
#
#
#
#
#                     | Cost Category | Value ($) | % of Total |
#             | ------------- | --------- | ---------- |
#             | Manufacturing | 120,000   | 40%        |
#             | Logistics     | 90,000    | 30%        |
#             | Returns       | 45,000    | 15%        |
#             | Miscellaneous | 45,000    | 15%        |
#
#
#
#               Inventory Status
#
#       Charts: Heatmap + Bullet Chart
#
#       Fields: Warehouse (Rows), ProductID (Columns), Inventory Status (Color)
#
#       Goal: Spot understocked / overstocked SKUs
#
#       Color Palette: Red = Understocked, Green = Healthy, Orange = Overstocked
#
#       Tooltip: StockLevel, SafetyStock, ReorderPoint, Category
#
#
#
#
#
#
#
#                 Order Fulfillment
#
#           Charts: Line Chart + KPI Cards
#
#           Fields: OrderDate (X-axis), DeliveryTime (Y-axis), Region (Color)
#
#           KPI Cards: Avg DeliveryTime, % On-Time, Total Orders
#
#           Goal: Track fulfillment efficiency over time and by geography
#
#
#
#
#
#                     +---------------------------------------------------------------+
#           | Dashboard Header: GlamourGlow Supply Chain                   |
#           | Filters: Warehouse, Product Category, Supplier, Date Range   |
#           +---------------------------------------------------------------+
#           | KPI Cards: Total Orders, Avg Delivery Time, Stock Coverage, On-Time % |
#           +---------------------------------------------------------------+
#           | Module 1: Inventory Heatmap + Bullet Chart                  |
#           +---------------------------------------------------------------+
#           | Module 2: Order Fulfillment Line Chart + KPI Cards          |
#           +---------------------------------------------------------------+
#           | Module 3: Supplier Scatter Plot + Table                     |
#           +---------------------------------------------------------------+
#           | Module 4: Shipping Bar Chart + Map                          |
#           +---------------------------------------------------------------+
#           | Module 5: Cost Pie Chart + Time Series                      |
#           +---------------------------------------------------------------+
#           | Module 6: Strategic Insights / Action Plan                 |
#           +---------------------------------------------------------------+
